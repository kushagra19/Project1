# %%
## Creating data for green component

#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as spfft
import scipy.ndimage as spimg
import imageio
# Discrete Cosine Transform
def dct2(x):
    return spfft.dct(spfft.dct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)

def idct2(x):
    return spfft.idct(spfft.idct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)


#Declaring path variable
path = "/Users/kushagrakhatwani/MDS/Project1/Problem4&5" #Change path to your own directory

zoom_out = 0.9999999  # Fraction of the image you want to keep.

#keep corruption same as what you used in random indices.ipynb
corruption = 0.7  # Fraction of the pixels that you want to discard

# Get image and create y

# read original image and downsize for speed
Xorig = imageio.imread(path+'/img.png', pilmode='RGB')  #read in in RGB

#Import random indices array
ri = np.load(path+"/ri.npy")
print(Xorig.shape)
# Downsize image
X = spimg.zoom(Xorig, zoom_out)
print(X.shape)
ny, nx ,nz= X.shape
print(ny,nx)
# extract small sample of signal
corruption = 1 - corruption
# k = round(nx * ny *corruption)
# ri = np.random.choice(nx*ny, k, replace=False)  # random sample of indices
b = X[:,:,1].T.flat[ri]
b = np.expand_dims(b, axis=1)
#%% CREATE A inverse and C
# *******************************************************************************************
"""This part consumes a lot of memory. Your PC might crash if the images you load are larger than 100 x 100 pixels """
# create dct matrix operator using kron (memory errors for large ny*nx)
Aa = np.kron(
    np.float16(spfft.idct(np.identity(nx), norm='ortho', axis=0)),
    np.float16(spfft.idct(np.identity(ny), norm='ortho', axis=0))
)
A = Aa[ri, :]  # same as B times A
# *******************************************************************************************
# create images of mask (for visualization)

#Store only green component in the tmp array
tmp = X[:,:,1]
mask = np.zeros((X.shape[0],X.shape[1]))
mask.T.flat[ri] = True
mask[mask == 0] = False
masked = tmp * mask
Xm = np.ones(X.shape)
Xm.T.flat[ri] = tmp.T.flat[ri]/255
#%%
plt.imshow(X)
plt.title("Original")
plt.show()

plt.imshow(masked,cmap='gray')
plt.title("Mask")
plt.show()
#%% SAVE MATRICES TO DRIVE
import os
dir_name = "Data For Assignment"
try:
    os.mkdir(dir_name)
except Exception as e:
    pass

np.save(dir_name + '/C', A)
np.save(dir_name + '/A_inv', Aa)
np.save(dir_name + '/y', b)
plt.imsave(dir_name + '/incomplete.png', Xm)
plt.imsave(dir_name + '/original_with_crop.png', X)
# Out:
# (100, 100, 3)
# (100, 100, 3)
# 100 100
