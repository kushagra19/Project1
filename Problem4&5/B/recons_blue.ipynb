# %%
#Importing Libraries
import numpy as np
import cvxpy as cp
import dccp
import scipy.fftpack as spfft
import matplotlib.pyplot as plt
#Importing themes
# from jupyterthemes import jtplot
# jtplot.style(theme = "monokai",context = "notebook", ticks = True,grid = False)

# %%
#Paths to numpy arrays
path = '/Users/kushagrakhatwani/MDS/Project1//Problem4&5/G/Data for Assignment' #Give path to your own directory

#Incomplete representaion of x
y = np.load(path+'/y.npy')
print("y_Shape:",y.shape)

#A inverse array
A_inv = np.load(path+'/A_inv.npy')
print("A_inv_Shape:",A_inv.shape)

#C matrix used for y = Cs where s is the sparse representation
c = np.load(path+'/C.npy')
print("C_shape:",c.shape)
print(cp.installed_solvers())
# Out:
# y_Shape: (3000, 1)
# A_inv_Shape: (10000, 10000)
# C_shape: (3000, 10000)
# ['CVXOPT', 'ECOS', 'ECOS_BB', 'GLPK', 'GLPK_MI', 'GUROBI', 'OSQP', 'SCIPY', 'SCS']

# %%
#Convex Optimization using cvxpy solver
#Declaring variable
s = cp.Variable((A_inv.shape[0],1))
#Objective function
f = cp.norm(s,1)
obj = cp.Minimize(f)
#Constraints
cnsts = [y == c@s]
#Problem formulation
prob = cp.Problem(obj,cnsts)
#Checking if problem satisfies disciplined convex programming
print(prob.is_dcp(prob))
#Finding optimal value using solve
opt_val = prob.solve(verbose=True,solver = 'OSQP')
#Store value in sol
sol = s.value
# Out:
# True
# ===============================================================================
#                                      CVXPY
#                                     v1.1.15
# ===============================================================================
# (CVXPY) Nov 11 01:25:03 AM: Your problem has 10000 variables, 1 constraints, and 0 parameters.
# (CVXPY) Nov 11 01:25:03 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 11 01:25:03 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 11 01:25:03 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 11 01:25:03 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Nov 11 01:25:03 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Nov 11 01:25:03 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 11 01:25:03 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Nov 11 01:25:03 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Nov 11 01:25:21 AM: Applying reduction OSQP
# (CVXPY) Nov 11 01:25:23 AM: Finished problem compilation (took 1.930e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 11 01:25:23 AM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 20001, constraints m = 23001
#           nnz(P) + nnz(A) = 29563701
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1  -7.6205e+04   2.48e+02   8.15e+08   1.00e-01   6.59e+01s
#  200   1.0538e+05   6.97e-01   2.12e-01   1.00e-01   8.42e+01s
#  400   1.0492e+05   1.69e-01   1.67e-02   1.00e-01   1.03e+02s
#  600   1.0488e+05   1.17e+00   2.79e-03   2.09e-03   1.84e+02s
#  800   1.0489e+05   2.02e-01   9.34e-04   2.09e-03   2.01e+02s
# 1000   1.0489e+05   3.65e-01   1.71e-04   2.34e-04   2.73e+02s
# 1200   1.0489e+05   1.66e-01   8.07e-05   2.34e-04   2.88e+02s
# 1400   1.0489e+05   1.03e-01   4.71e-05   2.34e-04   3.04e+02s
# 1600   1.0489e+05   7.22e-02   3.24e-05   2.34e-04   3.21e+02s
# 1800   1.0489e+05   5.31e-02   2.44e-05   2.34e-04   3.37e+02s
# 1950   1.0489e+05   5.90e-02   1.94e-05   2.34e-04   3.49e+02s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 1950
# optimal objective:    104894.0846
# run time:             4.08e+02s
# optimal rho estimate: 8.66e-05
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 11 01:32:12 AM: Problem status: optimal
# (CVXPY) Nov 11 01:32:12 AM: Optimal value: 1.050e+05
# (CVXPY) Nov 11 01:32:12 AM: Compilation took 1.930e+01 seconds
# (CVXPY) Nov 11 01:32:12 AM: Solver (including time spent in interface) took 4.098e+02 seconds

# %%
#Reshape s as intitially columns were stacked into one row
s_reshape = np.reshape(sol,(100,100))
print(s_reshape.shape)
#Inverse cosine transform for the reconstruction of the image
def idct2(x):
    return spfft.idct(spfft.idct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)
#Storing reconstruted image into x_blue
x_blue = idct2(s_reshape.T)
# Out:
# (100, 100)

# %%
#Reconstructed image(only blue component)
plt.imshow(x_blue,cmap = 'Blues')
#saving green part into an array,will be later on combined with other components
#to form full RGB image
np.save("Blue.npy",x_blue)
