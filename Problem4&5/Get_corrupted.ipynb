# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imageio
#for themes
# from jupyterthemes import jtplot
# jtplot.style(theme = "monokai",context = "notebook", ticks = True,grid = False)

# %%
path = "/Users/kushagrakhatwani/MDS/Project1/Problem5"

r = imageio.imread(path+"/R/Data for Assignment/incomplete.png",pilmode='L')

print(r.shape)
# Out:
# (100, 100)

# %%
g = imageio.imread(path+"/G/Data for Assignment/incomplete.png",pilmode='L')

print(r.shape)
# Out:
# (100, 100)

# %%
b = imageio.imread(path+"/B/Data for Assignment/incomplete.png",pilmode='L')

print(r.shape)
# Out:
# (100, 100)

# %%
im = np.zeros((100,100,3))
print(im.shape)

#Normalizing images so all pixel intensity values lie between 0-255
im[:,:,0] = (r-np.min(r))/(np.max(r)-np.min(r))
im[:,:,1] = (g-np.min(g))/(np.max(g)-np.min(g))
im[:,:,2] = (b-np.min(b))/(np.max(b)-np.min(b))
# Out:
# (100, 100, 3)

# %%
plt.imshow(im)
